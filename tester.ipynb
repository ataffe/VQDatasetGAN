# %%
import numpy as np
import albumentations

# %%
cropper = albumentations.RandomCrop(height=256, width=256)
cropper = albumentations.Compose([cropper], additional_targets={"coord": "image"})

coord = np.arange(256, 256).reshape(256, 256, 1) / (256 * 256)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cropper = albumentations.RandomCrop(height=256, width=256)
#       2 cropper = albumentations.Compose([cropper], additional_targets={})
#       4 coord = np.arange(256, 256).reshape(256, 256, 1) / (256 * 256)
#
# NameError: name 'albumentations' is not defined

# %%
"print(mat)
# Out:
# [[[0.   ]
#   [0.005]
#   [0.01 ]
#   [0.015]
#   [0.02 ]
#   [0.025]
#   [0.03 ]
#   [0.035]
#   [0.04 ]
#   [0.045]
#   [0.05 ]
#   [0.055]
#   [0.06 ]
#   [0.065]
#   [0.07 ]
#   [0.075]
#   [0.08 ]
#   [0.085]
#   [0.09 ]
#   [0.095]]
#
#  [[0.1  ]
#   [0.105]
#   [0.11 ]
#   [0.115]
#   [0.12 ]
#   [0.125]
#   [0.13 ]
#   [0.135]
#   [0.14 ]
#   [0.145]
#   [0.15 ]
#   [0.155]
#   [0.16 ]
#   [0.165]
#   [0.17 ]
#   [0.175]
#   [0.18 ]
#   [0.185]
#   [0.19 ]
#   [0.195]]
#
#  [[0.2  ]
#   [0.205]
#   [0.21 ]
#   [0.215]
#   [0.22 ]
#   [0.225]
#   [0.23 ]
#   [0.235]
#   [0.24 ]
#   [0.245]
#   [0.25 ]
#   [0.255]
#   [0.26 ]
#   [0.265]
#   [0.27 ]
#   [0.275]
#   [0.28 ]
#   [0.285]
#   [0.29 ]
#   [0.295]]
#
#  [[0.3  ]
#   [0.305]
#   [0.31 ]
#   [0.315]
#   [0.32 ]
#   [0.325]
#   [0.33 ]
#   [0.335]
#   [0.34 ]
#   [0.345]
#   [0.35 ]
#   [0.355]
#   [0.36 ]
#   [0.365]
#   [0.37 ]
#   [0.375]
#   [0.38 ]
#   [0.385]
#   [0.39 ]
#   [0.395]]
#
#  [[0.4  ]
#   [0.405]
# ...
